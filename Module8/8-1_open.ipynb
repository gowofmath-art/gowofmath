# %% [markdown]
# ##### `open()` 函式
# |`"r"`|`"a"`|`"w"`|`"x"`|`"t"`|`"b"`|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |read|append|write|create|text|binary|

# %% [markdown]
# ##### 讀取檔案 read( )

# %%
# 印出 50 個 "="
print("="*50)

# 讀取檔案內容 - 常用的寫法 (執行完畢會自動關閉檔案)
with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
    texts = f.read()
print(texts)

# 印出 50 個 "="
print("="*50)
# Out:
# ==================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 print("="*50)
#       4 # 讀取檔案內容 - 常用的寫法 (執行完畢會自動關閉檔案)
# ----> 5 with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
#       6     texts = f.read()
#       7 print(texts)
#
# TypeError: open() missing 1 required positional argument: 'file'

# %%
# 一行一行讀取
with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
    for line in f:
        print(line)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 一行一行讀取
# ----> 2 with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
#       3     for line in f:
#       4         print(line)
#
# TypeError: open() missing 1 required positional argument: 'file'

# %%
with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
    text_list = f.readlines()
    
    print(text_list)

# %%
# 資料處理
with open(flie="../Module2/2-1.py" , mode="r",encoding="utf-8") as f:
    text_list = f.readlines()

result = []
while '\n' in text_list:
    text_list.remove('\n')

for text in text_list:
    text_without_n = text.re

# %% [markdown]
# ##### 寫入檔案 write( )

# %%
# 文字內容
text = '''
傑出的人會努力規劃自己的人生，普通的人則是隨便命運怎麼安排   
一個是充實、有目的的過每一天，一個是隨興的過一天算一天
創業這條路 Michael E.Gerber
'''

# 寫入檔案
with open('test.txt','w',encoding='utf-8') as f:
    f.write(text)

# %%
# 寫入資料到最後一行 (附加文字在檔案內容最後一行)
text = "People say that success just happens to you. It doesn't!"
with open('test.txt','a',encoding='utf-8') as f:
    f.write(text+'\n')

    
# People say that success just happens to you. It doesn't!
