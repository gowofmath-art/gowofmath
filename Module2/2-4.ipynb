# %% [markdown]
# | | |
# |:---|:---|
# | | |

# %% [markdown]
# 算術運算子

# %%
a = 19
b = 4
c = 2 
print(a+b)
print(a-b)
print(a*b)
print(b**c)
print(a//b)
print(a%b)
# Out:
# 23
# 15
# 76
# 16
# 4
# 3

# %% [markdown]
# 賦值運算子

# %%
a = 4
b = 5

b += a
print(b)
# Out:
# 9

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %%
a = 4
b = 5 
c = 2+2
print(a==b)
print(a!=b)
print(a==c)
print (a+b)
if a != b:   #if 為 ture 就要執行縮排內的程式碼
    print("a 不等於 b")
    print("不管怎樣都會執行")    #shift+tab 反縮排
# Out:
# False
# True
# True
# 9
# a 不等於 b
# 不管怎樣都會執行

# %%
score = 50
passing_score = 60

if score < passing_score:
    score += 5

print("最終成績:")
print(score)
# Out:
# 最終成績:
# 55

# %% [markdown]
# 邏輯運算子 and / or / not

# %%
x = 3
y = 7 
if x+y == 10 and x-y == -4:
    print("對的")

if y-x <=-10 or x+y == 15:
    print("很棒")

if not x == 8:
    print("因為是錯的，所以才顯示出來！")
# Out:
# 對的
# 因為是錯的，所以才顯示出來！

# %% [markdown]
# 成員運算子 in / not in

# %%
lucky_numbers = [1,3,5]

x = 5
if x in lucky_numbers:
    print("恭喜")

if 97 not in lucky_numbers:
    print("沒有喔")
# Out:
# 恭喜
# 沒有

# %% [markdown]
# 身分運算子 is / is not

# %%
# list 賦值給變數，會參照到不同的記憶體位置
x= {1,2}
y= {1,2}

print(x is y)
print(id(x))
print(id(y))
#如果是數字 就會是 true
print(x == y)
# is 只是拿來判斷記憶體是否一樣
# Out:
# False
# 1620074994976
# 1620074995648
# True

# %% [markdown]
# 位元運算子

# %%
x = 3
y = 5

print(x&y)
print(x|y)
print(x^y)
# Out:
# 1
# 7
# 6
