# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
a = 2000
total = a
if a >= 2000:
    a = a-200

print(a)
# Out:
# 1800

# %%
# 滿2000 折價200 滿4000 折價 400 以此類推
a = 4321
total = a
if a >= 2000:
    a = a-200*(a//2000)

print(a)
# Out:
# 3921

# %%
s="apple"
print(s[::-1])
# Out:
# elppa
