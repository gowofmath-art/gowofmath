# %% [markdown]
# |基本型態|創建方式|
# |:---:|:---:|
# | int | num = 10 |
# | float | num2 = 3.14 |
# | boolean |  |
# | string |  |

# %% [markdown]
# |容器型態|創建方式|
# |:---:|:---:|
# |list| |num=[2, 4, 6] |
# |tuple|class_tup = ("name":"ball" , "age" : 29)|
# |set|set = {1, 2, 3}|
# |dict||

# %% [markdown]
# 整數 (int)、浮點數 (float)

# %%
from math import *
x_1= 6
x_2= 3.14159
x_3=3/7
x_4=math.pi   
print(x_1)
print(x_2)
print(x_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 5
#       3 x_2= 3.14159
#       4 x_3=3/7
# ----> 5 x_4=math.pi
#       6 print(x_1)
#       7 print(x_2)
#
# NameError: name 'math' is not defined

# %% [markdown]
# 布林值 (boolean)

# %%
parse_ok=True
parse_not_ok=False
print(parse_ok)
print(parse_not_ok)
# Out:
# True
# False

# %% [markdown]
# 字串 (string)

# %%
x="5"
y=7
# type() 檢查資料型別
print(type(x)) 
print(type(y))

total = x+y
print(total)
# Out:
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       4 print(type(x))
#       5 print(type(y))
# ----> 6 total = x+y
#       7 print(total)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = "apple"
movie = "hello world!"
print(name)
print(movie)
# Out:
# apple
# hello world!

# %% [markdown]
# 列表 (list)

# %%
my_list = [4, 5, 6]
print(my_list)
# Out:
# [4, 5, 6]

# %% [markdown]
# 元組 (tuple)

# %%
class_tup = ("A", "B", "C", "A")
print(class_tup)
print(type(class_tup))
# Out:
# ('A', 'B', 'C', 'A')
# <class 'tuple'>

# %% [markdown]
# 集合 (set)

# %%
set = {1, 2, 3, 1}
print(set)
print(type(set))
# Out:
# {1, 2, 3}
# <class 'set'>

# %% [markdown]
# 字典 (dict)

# %%
user = {"name": "julia", "age": 28}
print(user)
print(type(user))
print(type(class_tup))
# Out:
# {'name': 'julia', 'age': 28}
# <class 'dict'>
# <class 'tuple'>

# %%
#  建立空的 list
data = []
print(data)
print(type(data))
# Out:
# []
# <class 'list'>

# %%
# 創建一個空的 dict
data = {}
print(data)
print(type(data))
# Out:
# {}
# <class 'dict'>

# %%
# 創建一個空的 set
data = set()
print(data)
print(type(data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # 創建一個空的 set
# ----> 2 data = set()
#       3 print(data)
#       4 print(type(data))
#
# TypeError: 'set' object is not callable
