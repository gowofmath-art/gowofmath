# %%
# ipynb 檔案 才可以用以下
# esc 跳出
# ctrl+enter 執行
# A 往上新增
# B 往下新增
# X 刪除

# %%
from math import *
x=2**5
x=7
name= x*x
print(x)
print(name)
# Out:
# 7
# 49

# %%
# VS Code 的快捷鍵操作
# Alt 按著 可以選取該列程式碼來做移動
# Ctrl+D 可以一次選取多個變數  方便一次修改
# Alt+Shift +方向 ：複製某一列程式碼
# Ctrl+`：打開(關閉) 終端機
# Ctrl+
# 常用大寫去命名 常數  ((一般變數一律都用小寫)
