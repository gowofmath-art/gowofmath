# %%
# 自訂例外處理
def pdf_func(page):
    if page <= 0:
        raise ValueError("Page 不能小於0")
    if page <= 0:
        raise ValueError("Page 不可小於0")
pdf_func([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5     if page <= 0:
#       6         raise ValueError("Page 不可小於0")
# ----> 7 pdf_func([1,2,3])
#
# Cell In[1], line 3, in pdf_func(page)
#       2 def pdf_func(page):
# ----> 3     if page <= 0:
#       4         raise ValueError("Page 不能小於0")
#       5     if page <= 0:
#
# TypeError: '<=' not supported between instances of 'list' and 'int'

# %%
# 自訂型別錯誤(TypeError)的例外處理

# %% [markdown]
# ##### 設計 raise 陳述

# %%
def get_user_data(permission , user_class):
    if permission != "Treacher":
        raise PermissionError("權限錯誤")
    if user_class != "bigdata":
        raise ValueError("班錯誤")
    
    return [49,69,22,30]
try:
    grades = get_user_data("teacher", "AIPE")
except PermissionError as w:
    great = e
except ValueError as e:
    grades = e


print(grades)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 9
#       8 try:
# ----> 9     grades = get_user_data("teacher", "AIPE")
#      10 except PermissionError as w:
#
# Cell In[7], line 3, in get_user_data(permission, user_class)
#       2 if permission != "Treacher":
# ----> 3     raise PermissionError("權限錯誤")
#       4 if user_class != "bigdata":
#
# PermissionError: 權限錯誤
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       9     grades = get_user_data("teacher", "AIPE")
#      10 except PermissionError as w:
# ---> 11     great = e
#      12 except ValueError as e:
#      13     grades = e
#
# NameError: name 'e' is not defined
